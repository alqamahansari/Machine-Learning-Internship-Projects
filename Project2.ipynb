# %%
import statistics

# %%
scores = [56, 62, 68, 71, 75, 78, 82, 85, 88, 90, 92]
study_hours = [2, 3, 3, 4, 4, 5, 6, 6, 7, 8, 8]

# %%
mean = statistics.mean(scores)
print(mean)
# Out:
# 77

# %%
median = statistics.median(scores)
print(median)
# Out:
# 78

# %%
mode = statistics.mode(scores)
print(mode)
# Out:
# 56

# %%
variance = statistics.variance(scores)
print(variance)
# Out:
# 139.2

# %%
std = statistics.stdev(scores)
print(std)
# Out:
# 11.798304963002101

# %%
median_low = statistics.median_low(scores)
median_high = statistics.median_high(scores)

# %%
paired_data = list(zip(study_hours, scores))
print(paired_data)
# Out:
# [(2, 56), (3, 62), (3, 68), (4, 71), (4, 75), (5, 78), (6, 82), (6, 85), (7, 88), (8, 90), (8, 92)]

# %%
statistics.fmean(scores)
# Out:
# 77.0
